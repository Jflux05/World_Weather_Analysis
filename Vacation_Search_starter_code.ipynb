# %% [markdown]
# ## Deliverable 2. Create a Customer Travel Destinations Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps

# Import API key
from config import g_key

# Configure gmaps API key
gmaps.configure(api_key=g_key)

# %%
# 1. Import the WeatherPy_database.csv file. 
city_data_df = pd.read_csv("Weather_Database/WeatherPy_database.csv")
city_data_df.head()
# Out:
#    City_ID             City Country      Lat       Lng  Max Temp  Humidity  \
# 0        0       Butaritari      KI   3.0707  172.7902     81.55        79
# 1        1  Bambous Virieux      MU -20.3428   57.7575     82.65        65
# 2        2           Lompoc      US  34.6391 -120.4579     58.12        94
# 3        3            Kapaa      US  22.0752 -159.3190     75.52        75
# 4        4       Ereymentau      KZ  51.6199   73.1033     30.51        95
#
#    Cloudiness  Wind Speed   Current Description
# 0          97       14.83         moderate rain
# 1          40       13.80      scattered clouds
# 2           1       13.80                  mist
# 3          20        1.01  heavy intensity rain
# 4         100        9.66            light snow

# %%
# 2. Prompt the user to enter minimum and maximum temperature criteria 
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))
# Out:
# What is the minimum temperature you would like for your trip? 70
# What is the maximum temperature you would like for your trip? 98

# %%
# 3. Filter the city_data_df DataFrame using the input statements to create a new DataFrame using the loc method.
preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & \
                                       (city_data_df["Max Temp"] >= min_temp)]
preferred_cities_df.head(10)
# Out:
#     City_ID             City Country      Lat       Lng  Max Temp  Humidity  \
# 0         0       Butaritari      KI   3.0707  172.7902     81.55        79
# 1         1  Bambous Virieux      MU -20.3428   57.7575     82.65        65
# 3         3            Kapaa      US  22.0752 -159.3190     75.52        75
# 7         7      New Norfolk      AU -42.7826  147.0587     72.90        47
# 8         8       Bhainsdehi      IN  21.6467   77.6325     75.88        37
# 10       10          Rikitea      PF -23.1203 -134.9692     76.73        75
# 12       12          Itarema      BR  -2.9248  -39.9167     80.80        80
# 16       16       Georgetown      MY   5.4112  100.3354     84.13        71
# 19       19           Atuona      PF  -9.8000 -139.0333     78.69        77
# 22       22          Kahului      US  20.8947 -156.4700     74.84        94
#
#     Cloudiness  Wind Speed   Current Description
# 0           97       14.83         moderate rain
# 1           40       13.80      scattered clouds
# 3           20        1.01  heavy intensity rain
# 7           92        5.99       overcast clouds
# 8            0        3.62             clear sky
# 10          97        7.96       overcast clouds
# 12          53       15.52         broken clouds
# 16          20       10.36            few clouds
# 19           4       18.25             clear sky
# 22          75       25.32  heavy intensity rain

# %%
# 4a. Determine if there are any empty rows.
preferred_cities_df.count()
# Out:
# City_ID                255
# City                   255
# Country                255
# Lat                    255
# Lng                    255
# Max Temp               255
# Humidity               255
# Cloudiness             255
# Wind Speed             255
# Current Description    255
# dtype: int64

# %%
# 4b. Drop any empty rows and create a new DataFrame that doesn’t have empty rows.
clean_df = preferred_cities_df.dropna()
clean_df.count()
# Out:
# City_ID                255
# City                   255
# Country                255
# Lat                    255
# Lng                    255
# Max Temp               255
# Humidity               255
# Cloudiness             255
# Wind Speed             255
# Current Description    255
# dtype: int64

# %%
# 5a. Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = clean_df[["City", "Country", "Max Temp", "Current Description", "Lat", "Lng"]].copy()

# 5b. Create a new column "Hotel Name"
hotel_df["Hotel Name"] = ""
hotel_df.head(10)
# Out:
#                City Country  Max Temp   Current Description      Lat  \
# 0        Butaritari      KI     81.55         moderate rain   3.0707
# 1   Bambous Virieux      MU     82.65      scattered clouds -20.3428
# 3             Kapaa      US     75.52  heavy intensity rain  22.0752
# 7       New Norfolk      AU     72.90       overcast clouds -42.7826
# 8        Bhainsdehi      IN     75.88             clear sky  21.6467
# 10          Rikitea      PF     76.73       overcast clouds -23.1203
# 12          Itarema      BR     80.80         broken clouds  -2.9248
# 16       Georgetown      MY     84.13            few clouds   5.4112
# 19           Atuona      PF     78.69             clear sky  -9.8000
# 22          Kahului      US     74.84  heavy intensity rain  20.8947
#
#          Lng Hotel Name
# 0   172.7902
# 1    57.7575
# 3  -159.3190
# 7   147.0587
# 8    77.6325
# 10 -134.9692
# 12  -39.9167
# 16  100.3354
# 19 -139.0333
# 22 -156.4700

# %%
# 6a. Set parameters to search for hotels with 5000 meters.
params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key
}
    
# 6b. Iterate through the hotel DataFrame.
for index, row in hotel_df.iterrows():
    
    # 6c. Get latitude and longitude from DataFrame
    lat = row["Lat"]
    lng = row["Lng"]
    params["location"] = f"{lat}, {lng}"
    
    # 6d. Set up the base URL for the Google Directions API to get JSON data.
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

    # 6e. Make request and retrieve the JSON data from the search. 
    hotels = requests.get(base_url, params=params).json()
    
    # 6f. Get the first hotel from the results and store the name, if a hotel isn't found skip the city.
    try:
        hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
        print(hotels["results"][0]["name"] + " found, near " + row["City"])
    except:
        print("Hotel not found... skipping.")
# Out:
# Isles Sunset Lodge found, near Butaritari
# Casa Tia Villa found, near Bambous Virieux
# Sheraton Kauai Coconut Beach Resort found, near Kapaa
# The Shingles Riverside Cottages found, near New Norfolk
# Prince Rathore HOME found, near Bhainsdehi
# People ThankYou found, near Rikitea
# Sea Lounge! Bar, Club & Restaurant found, near Itarema
# Cititel Penang found, near Georgetown
# Villa Enata found, near Atuona
# Maui Seaside Hotel found, near Kahului
# Welcomhotel By ITC Hotels, Bay Island, Port Blair found, near Port Blair
# Paradise Inn found, near Avarua
# Observatory Guest House found, near Busselton
# K G N HOTEL found, near Dhanwar
# Molika Springs Motel found, near Moree
# Grage Hotel Bengkulu found, near Bengkulu
# Pousada Porto Praia found, near Arraial Do Cabo
# Valley Breeze Guest House found, near Grenville
# INN NEW HORIZON found, near Touros
# Hotel Kou-Bugny found, near Vao
# Shanti Maurice Resort & Spa found, near Souillac
# Legend Hotel found, near Lao Cai
# Tarumã Tropical Hotel found, near Conceicao Do Araguaia
# Chambres d'hôte "La Trinité" found, near Saint-Philippe
# Casa Dora, Bubaque found, near Bubaque
# Rancho Crepusculo found, near Nisia Floresta
# Fengshui Residence found, near Port-Gentil
# Uruna Bay Retreat found, near Kieta
# Posada Turistica Manapiare found, near Puerto Ayacucho
# Hotel Provincial found, near San Juan
# janelas do mar found, near Trairi
# Marriott's Ko Olina Beach Club found, near Makakilo City
# Salinas do Maragogi All Inclusive Resort found, near Maragogi
# Mantra Trilogy Cairns found, near Cairns
# Tarawa Boutique Hotel found, near Bairiki
# Bora-Bora Pearl Beach Resort & Spa found, near Faanui
# Ramada Hotel & Suites by Wyndham Ballina Byron found, near Ballina
# Hotel La Cuarta found, near Cabuyaro
# Nusa Island Retreat found, near Kavieng
# Sapriadi Appy found, near Galesong
# Hotel welma found, near Ourossogui
# Hilo Hawaiian Hotel found, near Hilo
# Mantra on Collins Hobart found, near Hobart
# Broadwater Mariner Resort found, near Geraldton
# Puri Brata found, near Bambanglipuro
# HS Hotsson Smart Acapulco found, near Acapulco
# JABIR HOTEL found, near Bandarbeyla
# Daru Lodge found, near Daru
# Pastori 1 Jemaat Polycarpus found, near Atambua
# Veranda Paul et Virginie Hotel & Spa found, near Grand Gaube
# Pesanggrahan Garam found, near Kalianget
# Praia Hotel Imbituba found, near Imbituba
# Cj's Travellers Inn found, near Gigmoto
# Juvinal Martin found, near Airai
# Batemans Bay Marina Resort found, near Batemans Bay
# Hotel not found... skipping.
# Posada Villaven C.A. found, near San Cristobal
# Hospitality Carnarvon found, near Carnarvon
# Hôtel Le Dronmi found, near Cayenne
# Kwepunha Retreat found, near Robertsport
# Desert Gardens Hotel - Ayers Rock Resort found, near Yulara
# The Espiritu Hotel found, near Luganville
# Redface Studios Meublés found, near Dakar
# HOTEL BOURAQ INDAH PERMAI found, near Barabai
# Rest House found, near Kuliyapitiya
# Le Manotel found, near Moerai
# Atlantis Hotel found, near Bathsheba
# Pine Tree Motel found, near Katherine
# Hotel Chik Chik Namibe found, near Namibe
# ROADSIDE B&B found, near Lavumisa
# Río Nabagana found, near Tubuala
# Raj Bhawan found, near Bela
# Taloa Heights found, near Alofi
# Keleti Beach Resort found, near Vaini
# Guest House Izonk found, near Kualakapuas
# 21 Degree Hostel found, near Beihai
# Link VII damai found, near Stabat
# Hotel Tesoro Los Cabos found, near Cabo San Lucas
# Leuaina Beach Resort and Spa found, near Lufilufi
# Auberge du Routard found, near Oussouye
# Shandrani Beachcomber Resort & Spa found, near Mahebourg
# Penginapan Kim found, near Biak
# OCHA Office found, near Zemio
# SanBiz Lodge found, near Kirakira
# Leisure Spring Hotel found, near Ondo
# Amiin Hotel found, near Eyl
# Welcombe Hotel found, near Trincomalee
# Hotel not found... skipping.
# La Residence Manakara found, near Manakara
# Blue Ridge Beach Resort found, near Davila
# Victor's Center Hotel found, near Guarabira
# Hotel Memory found, near Akyab
# Grand Kecubung Hotel found, near Pangkalanbuun
# Conrad Bora Bora Nui found, near Vaitape
# Scoop Guest House found, near Hithadhoo
# Hotel Bressan found, near Pontes E Lacerda
# Mini Hotel Central found, near Victoria
# Hotel BR 364 found, near Cacoal
# ibis Styles Mt Isa Verona found, near Mount Isa
# Hôtel & Restaurant DIANA Ambilobe found, near Ambilobe
# Motel 6 Sinton, TX found, near San Patricio
# HOTEL ARARAS found, near Aquidauana
# Hotel not found... skipping.
# Pension Oaoa found, near Tautira
# International Lodge Motel found, near Mackay
# Crôa Mares Hotel found, near Sao Jose Da Coroa Grande
# MMM K-TICHON found, near Miragoane
# Rancho Caíque found, near Florestopolis
# Pousada Porto De Canoas found, near Sao Joao Da Barra
# Nile Palace Hotel found, near Malakal
# "Plantation Bed and Breakfast found, near Saint-Joseph
# Estancia Ña Luisa found, near Nueva Germania
# Divi Village Golf & Beach Resort found, near Oranjestad
# Ciudadela Gonzalez found, near Chone
# HOTEL JIYA PALACE, ASIND found, near Asind
# Maringe Lagoon Lodge found, near Buala
# Hotel not found... skipping.
# Puri Brata found, near Srandakan
# Hotel Pigalle found, near Cabedelo
# Royal Exchange Hotel found, near Broken Hill
# Kandrian Station found, near Kandrian
# Hotel Xaguate found, near Sao Filipe
# Pousada e Restaurante Cheiro e Sabor found, near Itaueira
# Hotel On The Rock by Prasanthi found, near Kupang
# Hotel Luta Resort found, near Rantepao
# Floresta Amazonica Hotel found, near Alta Floresta
# Phama Lodge found, near Mocuba
# Storyboard Beach Resort found, near Kloulklubed
# Groote Eylandt Lodge found, near Alyangula
# Seagulls Inn Namatani found, near Namatanai
# Hotel Santika Luwuk found, near Luwuk
# Pennera Rakesh found, near Dhone
# M N D P found, near Randudongkal
# Axim Beach Resort And Spa found, near Axim
# Classic Bar found, near Ugep
# Desert Palms Alice Springs found, near Alice Springs
# Nancy Montanes Bernardo found, near Dicabisagan
# Mystic Sands Beachfront Accommodation found, near Neiafu
# Hotel not found... skipping.
# BON Hotel Waterfront Richards Bay found, near Richards Bay
# Raiders Hotel & Dive found, near Tulagi
# Sharif Plaza Hotel found, near Garissa
# Shelly Bay Resort found, near Hervey Bay
# Hotel Peace Land Ishigakijima found, near Ishigaki
# Tanna Lodge found, near Isangel
# Sahid Bela Ternate Hotel found, near Ternate
# Hotel not found... skipping.
# Ahipara Holiday Park found, near Ahipara
# Naivasha Hotel found, near Yambio
# Hotel Vitasoa found, near Antalaha
# Raybow International Hotel found, near Takoradi
# La Ode Husein found, near Katobu
# HAMDAN PLAZA HOTEL SALALAH, an HTG Hotel found, near Salalah
# CenDeluxe Hotel Tuy Hoa found, near Tuy Hoa
# Hotel not found... skipping.
# Bholaram Verma found, near Bhanpuri
# Hospedaje Santa Ana found, near Tame
# Hotel Delta found, near Diamantino
# Hotel California Todos Santos found, near Todos Santos
# Shamrock Beach Resort found, near Guimbal
# Hotel Nusantara Nabire found, near Nabire
# The Bannister - Hotel & Yacht Club found, near Samana
# Hotel not found... skipping.
# Omadhoo Inn found, near Mahibadhoo
# Vahmoneh Lodge Vanimo found, near Vanimo
# Backpackers Inn found, near Byron Bay
# PT PPI Lamongan Tambak C found, near Labuhan
# Osprey Beach Hotel found, near Cockburn Town
# ALETHEIA Appartement Sinnamary found, near Sinnamary
# Hotel not found... skipping.
# Cristhian Ortigoza found, near Yataity
# Minshuku Agaihama found, near Nishihara
# Kashmiri Hotal found, near Pasni
# Hotel RIKMAN Continental found, near Tura
# Montana Hotel Syariah found, near Martapura
# Hotel Panorama found, near Governador Valadares
# Reserva do Abiaí found, near Pitimbu
# Auki Motel found, near Auki
# HOTEL LA ROCA found, near Cartagena Del Chaira
# Pousada da Josefa found, near Alcantara
# Auto Hotel El Soñador found, near Ocos
# Pousada Tia Amélia found, near Oriximina
# Lazy River Motor Inn found, near Swan Hill
# Casa Alquiler Doña Yenner y Don Wacho found, near Valdez
# Labis Sunrise Farm found, near Labis
# Amazon Exploring Expedition - Eretzen Tá Lodge found, near Nauta
# Hostal Bugambilia found, near San Estanislao
# CeBlue Villas & Beach Resort found, near The Valley
# Tuiuiu Pantanal Hotel found, near Barao De Melgaco
# Hotel not found... skipping.
# Screensaver found, near Harper
# Hotel La Villa Couacou found, near Grand-Santi
# Ghanzi Farmhouse found, near Ghanzi
# Villa Mar Colina found, near Yeppoon
# Hôtel Trois Étoiles de Biltine found, near Biltine
# Butterfly Beach Hotel found, near Oistins
# Posada Paraiso found, near Kantunilkin
# WFP Guesthouse found, near Bria
# Ramah Kost KITA found, near Pemangkat
# Hotel palance found, near Puerto Quijarro
# Nuli Sapi found, near Samarai
# Balandra Hotel found, near Manta
# Majestic Oasis Apartments found, near Port Augusta
# Airport Lodge Kiunga found, near Kiunga
# Baliraya found, near Cavinti
# The Gem Hotel Beaufort found, near Beaufort
# Hotel Gilmart found, near Ortega
# Medhufushi Island Resort found, near Muli
# OYO Hotel Iramar found, near Aracruz
# Predio Livraria Ahmed found, near Chimoio
# Maunacaribe found, near Maunabo
# Lidera found, near Carutapera
# Hotel not found... skipping.
# Cititel Penang found, near Butterworth
# Mercure Padang found, near Padang
# Hostel khaga sardai road found, near Khaga
# Gîte kajeon found, near Poum
# Hotel Kontiki found, near Sao Francisco Do Sul
# Aipana Plaza Hotel found, near Boa Vista
# Sangalad Lodging found, near Ron
# Tour Eiffel Hotel Benin found, near Porto Novo
# Atlantic Sand Oasis found, near Arecibo
# Nam Long Hotel found, near Dong Hoi
# Pousada Monte Carmelo O Pão found, near Belmonte
# HOTEL ISABELA found, near Amahai
# KOPKAR Hotel Bintang Sintuk found, near Bontang
# Amerian Catamarca Park Hotel found, near Catamarca
# Hotel not found... skipping.
# Hotel Fórum found, near Luanda
# Naifaru Residence Guest House found, near Naifaru
# Hotel Parador El Buen Cafe found, near Hatillo
# Monhotel résidence Inn Adiake found, near Adiake
# Paradise Hotel found, near Wanning
# Amassi Hotel Gash found, near Kassala
# Hotel not found... skipping.
# penginapan citra alam found, near Sungaipenuh
# Tararaco found, near Camaguey
# Cafe Lala Rehan Restaurant found, near Jati
# Seven Corner View Homestay found, near Chaozhou
# Hotel Best View found, near Laguna De Perlas
# Jinhui Hotel found, near Maoming
# Hotel not found... skipping.
# Radisson Grenada Beach Resort found, near Saint-Georges
# OYO 2634 Griya Birowo Syariah found, near Wonosari
# Hotel not found... skipping.
# Haajy Guest House 1 found, near Kulhudhuffushi
# Hospedaje Eco found, near Lagunas
# Hotel Marilu found, near Vila Do Maio
# SAIVEN MALL (SAIVEN C.A.) found, near Anaco
# Rouba Residency found, near Ponnani
# Pousada dos Navegantes found, near Caravelas
# HOTEL ALEX FLAT found, near Coari
# Hotels in Lakshadweep Islands found, near Kavaratti
# STARiHOTEL Mansa found, near Mansa
# Hospedaje El Chino found, near San Rafael Del Sur

# %%
# Verify if there are any empty rows.
hotel_df.count()
# Out:
# City                   255
# Country                255
# Max Temp               255
# Current Description    255
# Lat                    255
# Lng                    255
# Hotel Name             255
# dtype: int64

# %%
# 7. Drop the rows where there is no Hotel Name.
clean_hotel_df = hotel_df.loc[(hotel_df["Hotel Name"]!='')]
clean_hotel_df.head(10)
# Out:
#                City Country  Max Temp   Current Description      Lat  \
# 0        Butaritari      KI     81.55         moderate rain   3.0707
# 1   Bambous Virieux      MU     82.65      scattered clouds -20.3428
# 3             Kapaa      US     75.52  heavy intensity rain  22.0752
# 7       New Norfolk      AU     72.90       overcast clouds -42.7826
# 8        Bhainsdehi      IN     75.88             clear sky  21.6467
# 10          Rikitea      PF     76.73       overcast clouds -23.1203
# 12          Itarema      BR     80.80         broken clouds  -2.9248
# 16       Georgetown      MY     84.13            few clouds   5.4112
# 19           Atuona      PF     78.69             clear sky  -9.8000
# 22          Kahului      US     74.84  heavy intensity rain  20.8947
#
#          Lng                           Hotel Name
# 0   172.7902                   Isles Sunset Lodge
# 1    57.7575                       Casa Tia Villa
# 3  -159.3190  Sheraton Kauai Coconut Beach Resort
# 7   147.0587      The Shingles Riverside Cottages
# 8    77.6325                  Prince Rathore HOME
# 10 -134.9692                      People ThankYou
# 12  -39.9167   Sea Lounge! Bar, Club & Restaurant
# 16  100.3354                       Cititel Penang
# 19 -139.0333                          Villa Enata
# 22 -156.4700                   Maui Seaside Hotel

# %%
# Verify that the cleaned Dataframe has a relevant sample size
clean_hotel_df.count()
# Out:
# City                   240
# Country                240
# Max Temp               240
# Current Description    240
# Lat                    240
# Lng                    240
# Hotel Name             240
# dtype: int64

# %%
# 8a. Create the output File (CSV)
output_data_file = "Vacation_Search/WeatherPy_Vacation.csv"

# 8b. Export the City_Data into a csv
clean_hotel_df.to_csv(output_data_file, index_label="City_ID")

# %%
# 9. Using the template add city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Weather</dt><dd>{Current Description} and {Max Temp}°F</dd>
</dl>
"""

# 10a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in clean_hotel_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = clean_hotel_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map. 
fig = gmaps.figure(center=(25.0, 30.0), zoom_level=1)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(marker_layer)


# 11b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
