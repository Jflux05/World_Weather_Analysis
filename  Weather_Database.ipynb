# %% [markdown]
# ### Create a new set of 2,000 random latitudes and longitudes.

# %%
# Import Dependencies: 

import pandas as pd
import numpy as np
from citipy import citipy
import time
from datetime import datetime
import requests

# Import API key 
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations:


lats = np.random.uniform(low=-90.000, high=90.000, size=2000)

lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

lat_lngs = zip(lats, lngs)

# %%
# Create a list for the latitudes and longitudes:

coordinates = list(lat_lngs)

# %%
# Create a list for holding cities:
cities=[]

# Identify the nearest city for each latitude and longitude combination:
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # if the city is unique, then add it to the list
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient data pool size.
len(cities)
# Out:
# 767

# %% [markdown]
# Retrieve the following information from the API call:
#
# - Latitude and longitude
# - Maximum temperature
# - Percent humidity
# - Percent cloudiness
# - Wind speed
# - Weather description (for example, clouds, fog, light rain, clear sky)

# %%
# Use the Starting URL to define the for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1



# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve the data
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather['sys']['country']
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_description = city_weather['weather'][0]['description']
        # Add the parsed data to the list
        city_data.append({"City": city.title(),
                          "Country": city_country,
                         "Lat": city_lat,
                          "Lng": city_lng,
                         "Max Temp": city_max_temp,
                         "Humidity": city_humidity,
                         "Cloudiness": city_clouds,
                         "Wind Speed": city_wind,
                         "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | butaritari
# Processing Record 2 of Set 1 | bambous virieux
# Processing Record 3 of Set 1 | lompoc
# Processing Record 4 of Set 1 | kapaa
# Processing Record 5 of Set 1 | ereymentau
# Processing Record 6 of Set 1 | bluff
# Processing Record 7 of Set 1 | adrar
# Processing Record 8 of Set 1 | new norfolk
# Processing Record 9 of Set 1 | bhainsdehi
# Processing Record 10 of Set 1 | saint-francois
# Processing Record 11 of Set 1 | rikitea
# Processing Record 12 of Set 1 | khatanga
# Processing Record 13 of Set 1 | itarema
# Processing Record 14 of Set 1 | linhares
# Processing Record 15 of Set 1 | urdzhar
# City not found. Skipping...
# Processing Record 16 of Set 1 | port elizabeth
# Processing Record 17 of Set 1 | punta arenas
# Processing Record 18 of Set 1 | karaul
# City not found. Skipping...
# Processing Record 19 of Set 1 | georgetown
# Processing Record 20 of Set 1 | ushuaia
# Processing Record 21 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 22 of Set 1 | cefalu
# Processing Record 23 of Set 1 | atuona
# Processing Record 24 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 25 of Set 1 | sorvag
# City not found. Skipping...
# Processing Record 26 of Set 1 | solnechnyy
# Processing Record 27 of Set 1 | iqaluit
# Processing Record 28 of Set 1 | kahului
# Processing Record 29 of Set 1 | albany
# Processing Record 30 of Set 1 | port blair
# Processing Record 31 of Set 1 | maloy
# Processing Record 32 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 33 of Set 1 | kazalinsk
# City not found. Skipping...
# Processing Record 34 of Set 1 | bredasdorp
# Processing Record 35 of Set 1 | avarua
# Processing Record 36 of Set 1 | dikson
# Processing Record 37 of Set 1 | grindavik
# Processing Record 38 of Set 1 | busselton
# Processing Record 39 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 40 of Set 1 | upernavik
# Processing Record 41 of Set 1 | yerbogachen
# Processing Record 42 of Set 1 | nanortalik
# Processing Record 43 of Set 1 | dhanwar
# Processing Record 44 of Set 1 | moree
# Processing Record 45 of Set 1 | derzhavinsk
# Processing Record 46 of Set 1 | ola
# Processing Record 47 of Set 1 | coatesville
# Processing Record 48 of Set 1 | cape town
# Processing Record 49 of Set 1 | puerto ayora
# Processing Record 50 of Set 1 | port alfred
# Processing Record 1 of Set 2 | bengkulu
# Processing Record 2 of Set 2 | jega
# Processing Record 3 of Set 2 | mataura
# Processing Record 4 of Set 2 | homer
# Processing Record 5 of Set 2 | naze
# Processing Record 6 of Set 2 | arraial do cabo
# Processing Record 7 of Set 2 | jamestown
# Processing Record 8 of Set 2 | grenville
# Processing Record 9 of Set 2 | vila franca do campo
# Processing Record 10 of Set 2 | touros
# Processing Record 11 of Set 2 | vao
# Processing Record 12 of Set 2 | tuktoyaktuk
# Processing Record 13 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 14 of Set 2 | torbay
# Processing Record 15 of Set 2 | kinsale
# Processing Record 16 of Set 2 | bay roberts
# Processing Record 17 of Set 2 | saskylakh
# Processing Record 18 of Set 2 | burghausen
# Processing Record 19 of Set 2 | hamina
# Processing Record 20 of Set 2 | norman wells
# Processing Record 21 of Set 2 | souillac
# Processing Record 22 of Set 2 | falealupo
# City not found. Skipping...
# Processing Record 23 of Set 2 | east london
# Processing Record 24 of Set 2 | lebu
# Processing Record 25 of Set 2 | kodiak
# Processing Record 26 of Set 2 | lao cai
# Processing Record 27 of Set 2 | ossora
# Processing Record 28 of Set 2 | conceicao do araguaia
# Processing Record 29 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 30 of Set 2 | gornoye loo
# Processing Record 31 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 32 of Set 2 | castro
# Processing Record 33 of Set 2 | qaanaaq
# Processing Record 34 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 35 of Set 2 | rawson
# Processing Record 36 of Set 2 | saint-philippe
# Processing Record 37 of Set 2 | bubaque
# Processing Record 38 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 39 of Set 2 | nisia floresta
# Processing Record 40 of Set 2 | port-gentil
# Processing Record 41 of Set 2 | genhe
# Processing Record 42 of Set 2 | kieta
# Processing Record 43 of Set 2 | hasaki
# Processing Record 44 of Set 2 | hermanus
# Processing Record 45 of Set 2 | puerto ayacucho
# Processing Record 46 of Set 2 | san juan
# Processing Record 47 of Set 2 | trairi
# Processing Record 48 of Set 2 | nikolskoye
# Processing Record 49 of Set 2 | teguldet
# Processing Record 50 of Set 2 | makakilo city
# Processing Record 1 of Set 3 | maragogi
# Processing Record 2 of Set 3 | barcelona
# Processing Record 3 of Set 3 | carthage
# Processing Record 4 of Set 3 | saint george
# Processing Record 5 of Set 3 | cairns
# Processing Record 6 of Set 3 | kaitangata
# Processing Record 7 of Set 3 | port hardy
# Processing Record 8 of Set 3 | bethel
# Processing Record 9 of Set 3 | bairiki
# Processing Record 10 of Set 3 | volkhov
# Processing Record 11 of Set 3 | faanui
# Processing Record 12 of Set 3 | ballina
# Processing Record 13 of Set 3 | cabuyaro
# Processing Record 14 of Set 3 | kavieng
# Processing Record 15 of Set 3 | galesong
# Processing Record 16 of Set 3 | chifeng
# Processing Record 17 of Set 3 | ourossogui
# Processing Record 18 of Set 3 | elat
# Processing Record 19 of Set 3 | hilo
# Processing Record 20 of Set 3 | jiblah
# Processing Record 21 of Set 3 | hobart
# Processing Record 22 of Set 3 | geraldton
# Processing Record 23 of Set 3 | mingshui
# Processing Record 24 of Set 3 | gumdag
# Processing Record 25 of Set 3 | tshikapa
# Processing Record 26 of Set 3 | tuatapere
# Processing Record 27 of Set 3 | bambanglipuro
# Processing Record 28 of Set 3 | acapulco
# Processing Record 29 of Set 3 | teguise
# Processing Record 30 of Set 3 | bandarbeyla
# Processing Record 31 of Set 3 | daru
# Processing Record 32 of Set 3 | gazojak
# Processing Record 33 of Set 3 | atambua
# Processing Record 34 of Set 3 | hokitika
# Processing Record 35 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 36 of Set 3 | grand gaube
# Processing Record 37 of Set 3 | ruatoria
# City not found. Skipping...
# Processing Record 38 of Set 3 | kalianget
# Processing Record 39 of Set 3 | rexburg
# Processing Record 40 of Set 3 | barrow
# Processing Record 41 of Set 3 | storm lake
# Processing Record 42 of Set 3 | tigzirt
# Processing Record 43 of Set 3 | imbituba
# Processing Record 44 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 45 of Set 3 | kirovskiy
# Processing Record 46 of Set 3 | horsham
# Processing Record 47 of Set 3 | ostrovnoy
# Processing Record 48 of Set 3 | axente sever
# Processing Record 49 of Set 3 | baraboo
# Processing Record 50 of Set 3 | gigmoto
# Processing Record 1 of Set 4 | leninsk
# Processing Record 2 of Set 4 | mao
# Processing Record 3 of Set 4 | airai
# Processing Record 4 of Set 4 | batemans bay
# Processing Record 5 of Set 4 | lagoa
# Processing Record 6 of Set 4 | klaksvik
# Processing Record 7 of Set 4 | jumla
# Processing Record 8 of Set 4 | arica
# Processing Record 9 of Set 4 | margate
# Processing Record 10 of Set 4 | safaga
# Processing Record 11 of Set 4 | molde
# Processing Record 12 of Set 4 | krasnoselkup
# Processing Record 13 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 14 of Set 4 | georgiyevka
# Processing Record 15 of Set 4 | saint-augustin
# Processing Record 16 of Set 4 | hofn
# Processing Record 17 of Set 4 | luan
# Processing Record 18 of Set 4 | manzil tamim
# City not found. Skipping...
# Processing Record 19 of Set 4 | thinadhoo
# Processing Record 20 of Set 4 | clyde river
# Processing Record 21 of Set 4 | san cristobal
# Processing Record 22 of Set 4 | carnarvon
# Processing Record 23 of Set 4 | cayenne
# Processing Record 24 of Set 4 | robertsport
# Processing Record 25 of Set 4 | yulara
# Processing Record 26 of Set 4 | yellowknife
# Processing Record 27 of Set 4 | luganville
# Processing Record 28 of Set 4 | lasa
# Processing Record 29 of Set 4 | ponta do sol
# Processing Record 30 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 31 of Set 4 | thompson
# Processing Record 32 of Set 4 | maple creek
# Processing Record 33 of Set 4 | finnsnes
# Processing Record 34 of Set 4 | burnie
# Processing Record 35 of Set 4 | dakar
# Processing Record 36 of Set 4 | paracatu
# Processing Record 37 of Set 4 | barabai
# Processing Record 38 of Set 4 | kuliyapitiya
# Processing Record 39 of Set 4 | shingu
# Processing Record 40 of Set 4 | voyinka
# Processing Record 41 of Set 4 | mahon
# Processing Record 42 of Set 4 | moerai
# Processing Record 43 of Set 4 | bathsheba
# Processing Record 44 of Set 4 | katherine
# Processing Record 45 of Set 4 | caohai
# Processing Record 46 of Set 4 | eureka
# Processing Record 47 of Set 4 | yayva
# Processing Record 48 of Set 4 | namibe
# Processing Record 49 of Set 4 | lavumisa
# Processing Record 50 of Set 4 | husavik
# Processing Record 1 of Set 5 | dire dawa
# Processing Record 2 of Set 5 | tubuala
# Processing Record 3 of Set 5 | bela
# Processing Record 4 of Set 5 | alofi
# Processing Record 5 of Set 5 | fortuna
# Processing Record 6 of Set 5 | vaini
# Processing Record 7 of Set 5 | ust-ishim
# Processing Record 8 of Set 5 | kualakapuas
# Processing Record 9 of Set 5 | nanae
# Processing Record 10 of Set 5 | kushiro
# Processing Record 11 of Set 5 | beihai
# Processing Record 12 of Set 5 | provideniya
# Processing Record 13 of Set 5 | severo-kurilsk
# Processing Record 14 of Set 5 | aklavik
# Processing Record 15 of Set 5 | berlevag
# Processing Record 16 of Set 5 | stabat
# Processing Record 17 of Set 5 | cabo san lucas
# Processing Record 18 of Set 5 | ketchikan
# Processing Record 19 of Set 5 | jalu
# Processing Record 20 of Set 5 | lufilufi
# Processing Record 21 of Set 5 | cervo
# Processing Record 22 of Set 5 | chagda
# City not found. Skipping...
# Processing Record 23 of Set 5 | oussouye
# Processing Record 24 of Set 5 | skovde
# City not found. Skipping...
# Processing Record 25 of Set 5 | varhaug
# Processing Record 26 of Set 5 | mahebourg
# Processing Record 27 of Set 5 | korla
# Processing Record 28 of Set 5 | biak
# Processing Record 29 of Set 5 | curitibanos
# Processing Record 30 of Set 5 | asayita
# City not found. Skipping...
# Processing Record 31 of Set 5 | saldanha
# Processing Record 32 of Set 5 | izberbash
# Processing Record 33 of Set 5 | banamba
# Processing Record 34 of Set 5 | rawannawi
# City not found. Skipping...
# Processing Record 35 of Set 5 | mar del plata
# Processing Record 36 of Set 5 | zemio
# Processing Record 37 of Set 5 | pevek
# Processing Record 38 of Set 5 | rendsburg
# Processing Record 39 of Set 5 | mastic
# Processing Record 40 of Set 5 | kirakira
# Processing Record 41 of Set 5 | tessalit
# Processing Record 42 of Set 5 | ondo
# Processing Record 43 of Set 5 | vestmanna
# Processing Record 44 of Set 5 | we
# City not found. Skipping...
# Processing Record 45 of Set 5 | skalistyy
# City not found. Skipping...
# Processing Record 46 of Set 5 | valparaiso
# Processing Record 47 of Set 5 | shaunavon
# Processing Record 48 of Set 5 | eyl
# Processing Record 49 of Set 5 | kenai
# Processing Record 50 of Set 5 | grantham
# Processing Record 1 of Set 6 | taoudenni
# Processing Record 2 of Set 6 | tasiilaq
# Processing Record 3 of Set 6 | kruisfontein
# Processing Record 4 of Set 6 | tasbuget
# City not found. Skipping...
# Processing Record 5 of Set 6 | trincomalee
# Processing Record 6 of Set 6 | camacupa
# Processing Record 7 of Set 6 | belyy yar
# Processing Record 8 of Set 6 | maraa
# Processing Record 9 of Set 6 | chapais
# Processing Record 10 of Set 6 | esperance
# Processing Record 11 of Set 6 | la ronge
# Processing Record 12 of Set 6 | bilma
# Processing Record 13 of Set 6 | manakara
# Processing Record 14 of Set 6 | arrifes
# Processing Record 15 of Set 6 | dudinka
# Processing Record 16 of Set 6 | chuy
# Processing Record 17 of Set 6 | coihaique
# Processing Record 18 of Set 6 | haines junction
# Processing Record 19 of Set 6 | ancud
# Processing Record 20 of Set 6 | chokurdakh
# Processing Record 21 of Set 6 | lushunkou
# City not found. Skipping...
# Processing Record 22 of Set 6 | bafra
# Processing Record 23 of Set 6 | nador
# Processing Record 24 of Set 6 | ribeira grande
# Processing Record 25 of Set 6 | davila
# Processing Record 26 of Set 6 | diego de almagro
# Processing Record 27 of Set 6 | guarabira
# Processing Record 28 of Set 6 | akyab
# Processing Record 29 of Set 6 | fairbanks
# Processing Record 30 of Set 6 | pangkalanbuun
# Processing Record 31 of Set 6 | chicama
# Processing Record 32 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 33 of Set 6 | vaitape
# Processing Record 34 of Set 6 | hithadhoo
# Processing Record 35 of Set 6 | carballo
# Processing Record 36 of Set 6 | pontes e lacerda
# Processing Record 37 of Set 6 | grottammare
# Processing Record 38 of Set 6 | zhanakorgan
# Processing Record 39 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 40 of Set 6 | tangzhai
# Processing Record 41 of Set 6 | dujuma
# City not found. Skipping...
# Processing Record 42 of Set 6 | victoria
# Processing Record 43 of Set 6 | cacoal
# Processing Record 44 of Set 6 | havre-saint-pierre
# Processing Record 45 of Set 6 | mount isa
# Processing Record 46 of Set 6 | ambilobe
# Processing Record 47 of Set 6 | asyut
# Processing Record 48 of Set 6 | malwan
# City not found. Skipping...
# Processing Record 49 of Set 6 | palmer
# Processing Record 50 of Set 6 | cherskiy
# Processing Record 1 of Set 7 | san patricio
# Processing Record 2 of Set 7 | carsamba
# Processing Record 3 of Set 7 | rocha
# Processing Record 4 of Set 7 | aquidauana
# Processing Record 5 of Set 7 | tukrah
# Processing Record 6 of Set 7 | envira
# Processing Record 7 of Set 7 | tautira
# Processing Record 8 of Set 7 | mackay
# Processing Record 9 of Set 7 | awjilah
# Processing Record 10 of Set 7 | sao jose da coroa grande
# Processing Record 11 of Set 7 | muramatsu
# Processing Record 12 of Set 7 | naugarzan
# City not found. Skipping...
# Processing Record 13 of Set 7 | bilibino
# Processing Record 14 of Set 7 | miragoane
# Processing Record 15 of Set 7 | challans
# Processing Record 16 of Set 7 | chuka
# Processing Record 17 of Set 7 | florestopolis
# Processing Record 18 of Set 7 | faya
# Processing Record 19 of Set 7 | pangnirtung
# Processing Record 20 of Set 7 | nouadhibou
# Processing Record 21 of Set 7 | botwood
# Processing Record 22 of Set 7 | sao joao da barra
# Processing Record 23 of Set 7 | dabola
# Processing Record 24 of Set 7 | barroualie
# City not found. Skipping...
# Processing Record 25 of Set 7 | tiksi
# Processing Record 26 of Set 7 | malakal
# Processing Record 27 of Set 7 | fort smith
# Processing Record 28 of Set 7 | saint-joseph
# Processing Record 29 of Set 7 | jesup
# Processing Record 30 of Set 7 | nueva germania
# Processing Record 31 of Set 7 | cidreira
# Processing Record 32 of Set 7 | oranjestad
# Processing Record 33 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 34 of Set 7 | chone
# Processing Record 35 of Set 7 | big spring
# Processing Record 36 of Set 7 | fort nelson
# Processing Record 37 of Set 7 | karratha
# Processing Record 38 of Set 7 | asind
# Processing Record 39 of Set 7 | prince rupert
# Processing Record 40 of Set 7 | corning
# Processing Record 41 of Set 7 | buala
# Processing Record 42 of Set 7 | filingue
# Processing Record 43 of Set 7 | calama
# Processing Record 44 of Set 7 | sitka
# Processing Record 45 of Set 7 | lujiang
# Processing Record 46 of Set 7 | tommot
# Processing Record 47 of Set 7 | srandakan
# Processing Record 48 of Set 7 | westpunt
# City not found. Skipping...
# Processing Record 49 of Set 7 | sorland
# Processing Record 50 of Set 7 | kathmandu
# Processing Record 1 of Set 8 | burgos
# Processing Record 2 of Set 8 | cabedelo
# Processing Record 3 of Set 8 | dzhebariki-khaya
# Processing Record 4 of Set 8 | broken hill
# Processing Record 5 of Set 8 | inta
# Processing Record 6 of Set 8 | metapan
# Processing Record 7 of Set 8 | nowy targ
# Processing Record 8 of Set 8 | kandrian
# Processing Record 9 of Set 8 | suntar
# Processing Record 10 of Set 8 | simao
# Processing Record 11 of Set 8 | sao filipe
# Processing Record 12 of Set 8 | chichibu
# Processing Record 13 of Set 8 | sebaco
# Processing Record 14 of Set 8 | itaueira
# Processing Record 15 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 16 of Set 8 | esna
# Processing Record 17 of Set 8 | katsuura
# Processing Record 18 of Set 8 | taksimo
# Processing Record 19 of Set 8 | kitui
# Processing Record 20 of Set 8 | kupang
# Processing Record 21 of Set 8 | rantepao
# Processing Record 22 of Set 8 | alta floresta
# Processing Record 23 of Set 8 | rio grande
# Processing Record 24 of Set 8 | chhatak
# Processing Record 25 of Set 8 | mocuba
# Processing Record 26 of Set 8 | north branch
# Processing Record 27 of Set 8 | hovd
# Processing Record 28 of Set 8 | rundu
# Processing Record 29 of Set 8 | sayanskiy
# City not found. Skipping...
# Processing Record 30 of Set 8 | kloulklubed
# Processing Record 31 of Set 8 | guerrero negro
# Processing Record 32 of Set 8 | edgewater
# Processing Record 33 of Set 8 | ilulissat
# Processing Record 34 of Set 8 | erzin
# Processing Record 35 of Set 8 | fukue
# Processing Record 36 of Set 8 | alyangula
# Processing Record 37 of Set 8 | yar-sale
# Processing Record 38 of Set 8 | namatanai
# Processing Record 39 of Set 8 | kalmar
# Processing Record 40 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 41 of Set 8 | paradwip
# City not found. Skipping...
# Processing Record 42 of Set 8 | luwuk
# Processing Record 43 of Set 8 | ogulin
# Processing Record 44 of Set 8 | onalaska
# Processing Record 45 of Set 8 | karatau
# Processing Record 46 of Set 8 | blakstad
# Processing Record 47 of Set 8 | dhone
# Processing Record 48 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 49 of Set 8 | randudongkal
# Processing Record 50 of Set 8 | deputatskiy
# Processing Record 1 of Set 9 | axim
# Processing Record 2 of Set 9 | yumen
# Processing Record 3 of Set 9 | kutno
# Processing Record 4 of Set 9 | srednekolymsk
# Processing Record 5 of Set 9 | ugep
# Processing Record 6 of Set 9 | kashi
# Processing Record 7 of Set 9 | nemuro
# Processing Record 8 of Set 9 | tabialan
# City not found. Skipping...
# Processing Record 9 of Set 9 | puerto baquerizo moreno
# Processing Record 10 of Set 9 | alice springs
# Processing Record 11 of Set 9 | tarata
# Processing Record 12 of Set 9 | shieli
# Processing Record 13 of Set 9 | dicabisagan
# Processing Record 14 of Set 9 | rio gallegos
# Processing Record 15 of Set 9 | neiafu
# Processing Record 16 of Set 9 | sheridan
# Processing Record 17 of Set 9 | tsaratanana
# Processing Record 18 of Set 9 | leh
# Processing Record 19 of Set 9 | vardo
# Processing Record 20 of Set 9 | vigrestad
# Processing Record 21 of Set 9 | richards bay
# Processing Record 22 of Set 9 | shu
# Processing Record 23 of Set 9 | tulagi
# Processing Record 24 of Set 9 | taburi
# City not found. Skipping...
# Processing Record 25 of Set 9 | purepero
# Processing Record 26 of Set 9 | garissa
# Processing Record 27 of Set 9 | senmonorom
# City not found. Skipping...
# Processing Record 28 of Set 9 | leningradskiy
# Processing Record 29 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 30 of Set 9 | hamilton
# Processing Record 31 of Set 9 | hervey bay
# Processing Record 32 of Set 9 | kasempa
# Processing Record 33 of Set 9 | morlaix
# Processing Record 34 of Set 9 | lumberton
# Processing Record 35 of Set 9 | roma
# Processing Record 36 of Set 9 | camacha
# Processing Record 37 of Set 9 | ishigaki
# Processing Record 38 of Set 9 | jasper
# Processing Record 39 of Set 9 | talaya
# Processing Record 40 of Set 9 | natchez
# Processing Record 41 of Set 9 | keokuk
# Processing Record 42 of Set 9 | vestmannaeyjar
# Processing Record 43 of Set 9 | westport
# Processing Record 44 of Set 9 | pisco
# Processing Record 45 of Set 9 | smithers
# Processing Record 46 of Set 9 | waipawa
# Processing Record 47 of Set 9 | palm valley
# Processing Record 48 of Set 9 | mount gambier
# Processing Record 49 of Set 9 | bani walid
# Processing Record 50 of Set 9 | mahabad
# Processing Record 1 of Set 10 | pingxiang
# Processing Record 2 of Set 10 | taltal
# Processing Record 3 of Set 10 | mudgee
# Processing Record 4 of Set 10 | andenes
# Processing Record 5 of Set 10 | kivsharivka
# Processing Record 6 of Set 10 | dunedin
# Processing Record 7 of Set 10 | pont-a-mousson
# Processing Record 8 of Set 10 | zhaoyuan
# Processing Record 9 of Set 10 | cockburn harbour
# City not found. Skipping...
# Processing Record 10 of Set 10 | beipiao
# Processing Record 11 of Set 10 | isangel
# Processing Record 12 of Set 10 | hope
# Processing Record 13 of Set 10 | hailar
# Processing Record 14 of Set 10 | ternate
# Processing Record 15 of Set 10 | arroio grande
# Processing Record 16 of Set 10 | merauke
# Processing Record 17 of Set 10 | ahipara
# Processing Record 18 of Set 10 | yambio
# Processing Record 19 of Set 10 | antalaha
# Processing Record 20 of Set 10 | mackenzie
# Processing Record 21 of Set 10 | takoradi
# Processing Record 22 of Set 10 | longyearbyen
# Processing Record 23 of Set 10 | nome
# Processing Record 24 of Set 10 | navapur
# City not found. Skipping...
# Processing Record 25 of Set 10 | katobu
# Processing Record 26 of Set 10 | salalah
# Processing Record 27 of Set 10 | abu samrah
# Processing Record 28 of Set 10 | wanxian
# Processing Record 29 of Set 10 | tuy hoa
# Processing Record 30 of Set 10 | zalantun
# Processing Record 31 of Set 10 | goundi
# Processing Record 32 of Set 10 | ulaanbaatar
# Processing Record 33 of Set 10 | brandon
# Processing Record 34 of Set 10 | rungata
# City not found. Skipping...
# Processing Record 35 of Set 10 | darhan
# Processing Record 36 of Set 10 | bhanpuri
# Processing Record 37 of Set 10 | tame
# Processing Record 38 of Set 10 | diamantino
# Processing Record 39 of Set 10 | half moon bay
# Processing Record 40 of Set 10 | todos santos
# Processing Record 41 of Set 10 | guimbal
# Processing Record 42 of Set 10 | nabire
# Processing Record 43 of Set 10 | samana
# Processing Record 44 of Set 10 | salamiyah
# Processing Record 45 of Set 10 | muyezerskiy
# Processing Record 46 of Set 10 | casper
# Processing Record 47 of Set 10 | aripuana
# Processing Record 48 of Set 10 | oyama
# Processing Record 49 of Set 10 | aksarka
# Processing Record 50 of Set 10 | mahibadhoo
# Processing Record 1 of Set 11 | vanimo
# Processing Record 2 of Set 11 | byron bay
# Processing Record 3 of Set 11 | labuhan
# Processing Record 4 of Set 11 | cockburn town
# Processing Record 5 of Set 11 | sinnamary
# Processing Record 6 of Set 11 | los llanos de aridane
# Processing Record 7 of Set 11 | bosobolo
# Processing Record 8 of Set 11 | krasnoye
# Processing Record 9 of Set 11 | yataity
# Processing Record 10 of Set 11 | necochea
# Processing Record 11 of Set 11 | nishihara
# Processing Record 12 of Set 11 | pasni
# Processing Record 13 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 14 of Set 11 | mandalgovi
# Processing Record 15 of Set 11 | burica
# City not found. Skipping...
# Processing Record 16 of Set 11 | gornopravdinsk
# Processing Record 17 of Set 11 | muros
# Processing Record 18 of Set 11 | nyurba
# Processing Record 19 of Set 11 | tura
# Processing Record 20 of Set 11 | san rafael
# Processing Record 21 of Set 11 | jiuquan
# Processing Record 22 of Set 11 | monte santo
# Processing Record 23 of Set 11 | praia da vitoria
# Processing Record 24 of Set 11 | cheremukhovo
# Processing Record 25 of Set 11 | muroto
# Processing Record 26 of Set 11 | martapura
# Processing Record 27 of Set 11 | governador valadares
# Processing Record 28 of Set 11 | toliary
# City not found. Skipping...
# Processing Record 29 of Set 11 | pitimbu
# Processing Record 30 of Set 11 | auki
# Processing Record 31 of Set 11 | saryozek
# Processing Record 32 of Set 11 | urumqi
# Processing Record 33 of Set 11 | koboldo
# City not found. Skipping...
# Processing Record 34 of Set 11 | cartagena del chaira
# Processing Record 35 of Set 11 | alcantara
# Processing Record 36 of Set 11 | pacific grove
# Processing Record 37 of Set 11 | kutum
# Processing Record 38 of Set 11 | ocos
# Processing Record 39 of Set 11 | strunino
# Processing Record 40 of Set 11 | oriximina
# Processing Record 41 of Set 11 | swan hill
# Processing Record 42 of Set 11 | valdez
# Processing Record 43 of Set 11 | bur gabo
# City not found. Skipping...
# Processing Record 44 of Set 11 | mayo
# Processing Record 45 of Set 11 | labis
# Processing Record 46 of Set 11 | sinop
# Processing Record 47 of Set 11 | stoyba
# City not found. Skipping...
# Processing Record 48 of Set 11 | viedma
# Processing Record 49 of Set 11 | lixourion
# Processing Record 50 of Set 11 | flin flon
# Processing Record 1 of Set 12 | anchorage
# Processing Record 2 of Set 12 | nauta
# Processing Record 3 of Set 12 | lavrentiya
# Processing Record 4 of Set 12 | larsnes
# Processing Record 5 of Set 12 | kvarkeno
# Processing Record 6 of Set 12 | aflu
# City not found. Skipping...
# Processing Record 7 of Set 12 | forestville
# Processing Record 8 of Set 12 | college
# Processing Record 9 of Set 12 | severnoye
# Processing Record 10 of Set 12 | san estanislao
# Processing Record 11 of Set 12 | the valley
# Processing Record 12 of Set 12 | gaspe
# Processing Record 13 of Set 12 | poronaysk
# Processing Record 14 of Set 12 | barao de melgaco
# Processing Record 15 of Set 12 | pinhao
# Processing Record 16 of Set 12 | semnan
# Processing Record 17 of Set 12 | oum hadjer
# Processing Record 18 of Set 12 | srostki
# Processing Record 19 of Set 12 | harper
# Processing Record 20 of Set 12 | aranos
# Processing Record 21 of Set 12 | grand-santi
# Processing Record 22 of Set 12 | ghanzi
# Processing Record 23 of Set 12 | yeppoon
# Processing Record 24 of Set 12 | biltine
# Processing Record 25 of Set 12 | olafsvik
# Processing Record 26 of Set 12 | san ramon
# Processing Record 27 of Set 12 | salisbury
# Processing Record 28 of Set 12 | tilichiki
# Processing Record 29 of Set 12 | sao joao del rei
# Processing Record 30 of Set 12 | saurimo
# Processing Record 31 of Set 12 | batsfjord
# Processing Record 32 of Set 12 | oistins
# Processing Record 33 of Set 12 | caraquet
# Processing Record 34 of Set 12 | kantunilkin
# Processing Record 35 of Set 12 | santa vitoria do palmar
# Processing Record 36 of Set 12 | zhigansk
# Processing Record 37 of Set 12 | ajdabiya
# Processing Record 38 of Set 12 | athol
# Processing Record 39 of Set 12 | te anau
# Processing Record 40 of Set 12 | bria
# Processing Record 41 of Set 12 | pemangkat
# Processing Record 42 of Set 12 | chumikan
# Processing Record 43 of Set 12 | luderitz
# Processing Record 44 of Set 12 | puerto quijarro
# Processing Record 45 of Set 12 | khandagayty
# Processing Record 46 of Set 12 | bermeo
# Processing Record 47 of Set 12 | samarai
# Processing Record 48 of Set 12 | manta
# Processing Record 49 of Set 12 | nichinan
# Processing Record 50 of Set 12 | tarko-sale
# Processing Record 1 of Set 13 | aswan
# Processing Record 2 of Set 13 | avera
# Processing Record 3 of Set 13 | port augusta
# Processing Record 4 of Set 13 | kiunga
# Processing Record 5 of Set 13 | vincennes
# Processing Record 6 of Set 13 | cavinti
# Processing Record 7 of Set 13 | beaufort
# Processing Record 8 of Set 13 | troitsko-pechorsk
# Processing Record 9 of Set 13 | ortega
# Processing Record 10 of Set 13 | muli
# Processing Record 11 of Set 13 | arlit
# Processing Record 12 of Set 13 | aracruz
# Processing Record 13 of Set 13 | kimberley
# Processing Record 14 of Set 13 | chimoio
# Processing Record 15 of Set 13 | ornskoldsvik
# Processing Record 16 of Set 13 | karasjok
# Processing Record 17 of Set 13 | port lincoln
# Processing Record 18 of Set 13 | maunabo
# Processing Record 19 of Set 13 | skibbereen
# Processing Record 20 of Set 13 | nuuk
# Processing Record 21 of Set 13 | chajul
# Processing Record 22 of Set 13 | carutapera
# Processing Record 23 of Set 13 | storvorde
# Processing Record 24 of Set 13 | tumannyy
# City not found. Skipping...
# Processing Record 25 of Set 13 | qandala
# Processing Record 26 of Set 13 | butterworth
# Processing Record 27 of Set 13 | karpogory
# Processing Record 28 of Set 13 | kem
# Processing Record 29 of Set 13 | padang
# Processing Record 30 of Set 13 | ventimiglia
# Processing Record 31 of Set 13 | olsztyn
# Processing Record 32 of Set 13 | kashan
# Processing Record 33 of Set 13 | akhalgori
# Processing Record 34 of Set 13 | narsaq
# Processing Record 35 of Set 13 | khaga
# Processing Record 36 of Set 13 | helena
# Processing Record 37 of Set 13 | springdale
# Processing Record 38 of Set 13 | naryan-mar
# Processing Record 39 of Set 13 | russell
# Processing Record 40 of Set 13 | mata
# Processing Record 41 of Set 13 | talnakh
# Processing Record 42 of Set 13 | louisbourg
# City not found. Skipping...
# Processing Record 43 of Set 13 | laurencekirk
# Processing Record 44 of Set 13 | doha
# Processing Record 45 of Set 13 | honningsvag
# Processing Record 46 of Set 13 | kaura namoda
# Processing Record 47 of Set 13 | ucluelet
# Processing Record 48 of Set 13 | virginia
# Processing Record 49 of Set 13 | bayir
# Processing Record 50 of Set 13 | kodinsk
# Processing Record 1 of Set 14 | poum
# Processing Record 2 of Set 14 | kerewan
# Processing Record 3 of Set 14 | makat
# Processing Record 4 of Set 14 | fort saint james
# Processing Record 5 of Set 14 | itarare
# Processing Record 6 of Set 14 | sao francisco do sul
# Processing Record 7 of Set 14 | boa vista
# Processing Record 8 of Set 14 | dryden
# Processing Record 9 of Set 14 | opobo
# City not found. Skipping...
# Processing Record 10 of Set 14 | ponta delgada
# Processing Record 11 of Set 14 | golubitskaya
# Processing Record 12 of Set 14 | ron
# Processing Record 13 of Set 14 | porto novo
# Processing Record 14 of Set 14 | arecibo
# Processing Record 15 of Set 14 | dong hoi
# Processing Record 16 of Set 14 | blyth
# Processing Record 17 of Set 14 | belmonte
# Processing Record 18 of Set 14 | amahai
# Processing Record 19 of Set 14 | bontang
# Processing Record 20 of Set 14 | pingliang
# Processing Record 21 of Set 14 | sobolevo
# Processing Record 22 of Set 14 | catamarca
# Processing Record 23 of Set 14 | yaan
# Processing Record 24 of Set 14 | luanda
# Processing Record 25 of Set 14 | naifaru
# Processing Record 26 of Set 14 | polunochnoye
# Processing Record 27 of Set 14 | egvekinot
# Processing Record 28 of Set 14 | wulanhaote
# City not found. Skipping...
# Processing Record 29 of Set 14 | noyabrsk
# Processing Record 30 of Set 14 | kostolac
# Processing Record 31 of Set 14 | udimskiy
# Processing Record 32 of Set 14 | launceston
# Processing Record 33 of Set 14 | sedelnikovo
# City not found. Skipping...
# Processing Record 34 of Set 14 | hatillo
# Processing Record 35 of Set 14 | zeya
# Processing Record 36 of Set 14 | aberdeen
# Processing Record 37 of Set 14 | adiake
# Processing Record 38 of Set 14 | ulety
# Processing Record 39 of Set 14 | yingcheng
# Processing Record 40 of Set 14 | wanning
# Processing Record 41 of Set 14 | zavitinsk
# Processing Record 42 of Set 14 | fevralsk
# City not found. Skipping...
# Processing Record 43 of Set 14 | kyra
# Processing Record 44 of Set 14 | kassala
# Processing Record 45 of Set 14 | prieska
# Processing Record 46 of Set 14 | pervomayskoye
# Processing Record 47 of Set 14 | mercedes
# Processing Record 48 of Set 14 | sao felix do xingu
# Processing Record 49 of Set 14 | fonte boa
# Processing Record 50 of Set 14 | diapaga
# Processing Record 1 of Set 15 | sungaipenuh
# Processing Record 2 of Set 15 | kayerkan
# Processing Record 3 of Set 15 | camaguey
# Processing Record 4 of Set 15 | jati
# Processing Record 5 of Set 15 | pietersburg
# Processing Record 6 of Set 15 | laguna
# Processing Record 7 of Set 15 | chaozhou
# Processing Record 8 of Set 15 | lata
# Processing Record 9 of Set 15 | dinguiraye
# Processing Record 10 of Set 15 | seabra
# Processing Record 11 of Set 15 | sortland
# Processing Record 12 of Set 15 | tuggurt
# City not found. Skipping...
# Processing Record 13 of Set 15 | mago
# Processing Record 14 of Set 15 | laguna de perlas
# Processing Record 15 of Set 15 | jamiltepec
# Processing Record 16 of Set 15 | isparta
# Processing Record 17 of Set 15 | sanming
# Processing Record 18 of Set 15 | barbar
# City not found. Skipping...
# Processing Record 19 of Set 15 | vestbygda
# City not found. Skipping...
# Processing Record 20 of Set 15 | boleslawiec
# Processing Record 21 of Set 15 | moron
# Processing Record 22 of Set 15 | maoming
# Processing Record 23 of Set 15 | high level
# Processing Record 24 of Set 15 | belle fourche
# Processing Record 25 of Set 15 | krasnaya gorbatka
# Processing Record 26 of Set 15 | west monroe
# Processing Record 27 of Set 15 | aleksandrovsk-sakhalinskiy
# Processing Record 28 of Set 15 | labutta
# City not found. Skipping...
# Processing Record 29 of Set 15 | saint-louis
# Processing Record 30 of Set 15 | jiroft
# City not found. Skipping...
# Processing Record 31 of Set 15 | den helder
# Processing Record 32 of Set 15 | aginskoye
# Processing Record 33 of Set 15 | saint-georges
# Processing Record 34 of Set 15 | wonosari
# Processing Record 35 of Set 15 | siderno
# Processing Record 36 of Set 15 | cedartown
# Processing Record 37 of Set 15 | el alto
# Processing Record 38 of Set 15 | atar
# Processing Record 39 of Set 15 | rudovci
# Processing Record 40 of Set 15 | sembe
# Processing Record 41 of Set 15 | synya
# Processing Record 42 of Set 15 | kulhudhuffushi
# Processing Record 43 of Set 15 | dien bien
# City not found. Skipping...
# Processing Record 44 of Set 15 | aldan
# Processing Record 45 of Set 15 | lagunas
# Processing Record 46 of Set 15 | mehamn
# Processing Record 47 of Set 15 | vila do maio
# Processing Record 48 of Set 15 | komsomolskiy
# Processing Record 49 of Set 15 | leshukonskoye
# Processing Record 50 of Set 15 | samalaeulu
# City not found. Skipping...
# Processing Record 1 of Set 16 | anaco
# Processing Record 2 of Set 16 | henties bay
# Processing Record 3 of Set 16 | ponnani
# Processing Record 4 of Set 16 | whitehorse
# Processing Record 5 of Set 16 | sarkand
# Processing Record 6 of Set 16 | rimbey
# Processing Record 7 of Set 16 | sisimiut
# Processing Record 8 of Set 16 | saint anthony
# Processing Record 9 of Set 16 | caravelas
# Processing Record 10 of Set 16 | canico
# Processing Record 11 of Set 16 | khatassy
# Processing Record 12 of Set 16 | coari
# Processing Record 13 of Set 16 | kavaratti
# Processing Record 14 of Set 16 | mansa
# Processing Record 15 of Set 16 | altay
# Processing Record 16 of Set 16 | inuvik
# Processing Record 17 of Set 16 | san rafael del sur
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Add the data to a new DataFrame.

# %%
# Check that the new city count from the data retreived is sufficient

len(city_data)
# Out:
# 699

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Butaritari      KI   3.0707  172.7902     81.55        79          97
# 1  Bambous Virieux      MU -20.3428   57.7575     82.65        65          40
# 2           Lompoc      US  34.6391 -120.4579     58.12        94           1
# 3            Kapaa      US  22.0752 -159.3190     75.52        75          20
# 4       Ereymentau      KZ  51.6199   73.1033     30.51        95         100
# 5            Bluff      NZ -46.6000  168.3333     56.80        56           8
# 6            Adrar      MR  20.5022  -10.0711     58.57        18         100
# 7      New Norfolk      AU -42.7826  147.0587     72.90        47          92
# 8       Bhainsdehi      IN  21.6467   77.6325     75.88        37           0
# 9   Saint-Francois      FR  46.4154    3.9054     37.67        93          90
#
#    Wind Speed   Current Description
# 0       14.83         moderate rain
# 1       13.80      scattered clouds
# 2       13.80                  mist
# 3        1.01  heavy intensity rain
# 4        9.66            light snow
# 5       23.47             clear sky
# 6       10.31       overcast clouds
# 7        5.99       overcast clouds
# 8        3.62             clear sky
# 9        2.30       overcast clouds

# %% [markdown]
# ### Export the DataFrame as a CSV file

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
